# %%
import pandas as pd
a=['Jwalitha','Ramya','Dhana','Mounika','Sri','Vamsi','Durga']
r=pd.Series(a,index=[67,43,44,89,34,45,23])
print(r)
# Out:
# 67    Jwalitha
# 43       Ramya
# 44       Dhana
# 89     Mounika
# 34         Sri
# 45       Vamsi
# 23       Durga
# dtype: object

# %%
df=pd.read_csv("/content/diabetcsv.csv")
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df=pd.read_excel("/content/grades_withnulls (1).xlsx")
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_excel("/content/grades_withnulls (1).xlsx",sheet_name=0)
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
import pandas as pd
df=pd.read_excel("/content/grades_withnulls (1).xlsx")
print(df.head())
print(df.tail(n=10))
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
import pandas as pd
df=pd.read_csv("/content/grades_withnulls.csv")
print(df.describe)
# Out:
# <bound method NDFrame.describe of      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/grades_withnulls.csv")
print(df.describe().T)
# Out:
#         count      mean       std  min  25%  50%  75%   max
# SEM1     14.0  8.992857  0.929404  7.7  8.0  9.1  9.8   9.9
# SEM2     17.0  9.000000  0.647109  8.0  9.0  9.1  9.3  10.0
# SEM3     16.0  9.100000  1.057670  7.0  9.2  9.3  9.9  10.0
# Placed   17.0  0.588235  0.507300  0.0  0.0  1.0  1.0   1.0

# %%
import pandas as pd
df=pd.read_csv("/content/grades_withnulls.csv")
print(df.shape)#get the rows and cols
print(df.shape[0])#no of rows only
print(df.shape[1])#no of columns only
# Out:
# (17, 7)
# 17
# 7

# %%
import pandas as pd
df=pd.read_csv("/content/grades_withnulls.csv")
print(df.columns)
l1=list(df.columns)
print(l1)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed']

# %%
import pandas as pd
df=pd.read_csv("/content/grades_withnulls.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   NaN   9.8  10.0     A       0
# 3    Mary        N   NaN   8.0   NaN     B       0
# 4    Jeen        K   NaN   9.1   9.9    A+       1
# 5     Raj        M   NaN   9.1   9.3     A       1
# 6  Hassan        V   9.9   9.0   9.2     A       1

# %%
df2.isnull().head(7)#the dataset containing false becomes true
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False   True  False  False  False   False
# 3  False     False   True  False   True  False   False
# 4  False     False   True  False  False  False   False
# 5  False     False   True  False  False  False   False
# 6  False     False  False  False  False  False   False

# %%
df2.isnull().tail(7)
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# 16  False     False  False  False  False  False   False

# %%
print(df2.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        7
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
print(df2.isnull().sum().sum())
# Out:
# 8

# %%
print(df2['SEM2'])#extracting col
# Out:
# 0     10.0
# 1      9.1
# 2      9.8
# 3      8.0
# 4      9.1
# 5      9.1
# 6      9.0
# 7      8.0
# 8      9.1
# 9      9.1
# 10     9.3
# 11     8.0
# 12     9.1
# 13     9.1
# 14     9.9
# 15     9.3
# 16     8.0
# Name: SEM2, dtype: float64

# %%
print(df2[['SEM1','SEM2']])#particular col
# Out:
#     SEM1  SEM2
# 0    9.8  10.0
# 1    8.9   9.1
# 2    NaN   9.8
# 3    NaN   8.0
# 4    NaN   9.1
# 5    NaN   9.1
# 6    9.9   9.0
# 7    7.7   8.0
# 8    NaN   9.1
# 9    NaN   9.1
# 10   NaN   9.3
# 11   7.7   8.0
# 12   9.8   9.1
# 13   8.9   9.1
# 14   9.3   9.9
# 15   9.9   9.3
# 16   7.7   8.0

# %%
print(df2[df2.index==1])#particular row
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1  Rajesh        M   8.9   9.1   9.3     A       1

# %%
print(df2[df2.index.isin(range(5,9))])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 5     Raj        M   NaN   9.1   9.3     A       1
# 6  Hassan        V   9.9   9.0   9.2     A       1
# 7    Mari        N   7.7   8.0   7.1     B       1
# 8    Jess        K   NaN   9.1   9.9    A+       1

# %%
print(df.loc[1])#1st row
# Out:
# Names       Rajesh
# Initials         M
# SEM1           8.9
# SEM2           9.1
# SEM3           9.3
# Grade            A
# Placed           1
# Name: 1, dtype: object

# %%
df2.loc[6:11,'SEM1']==None#rows with range
# Out:
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# Name: SEM1, dtype: bool

# %%
df2.loc[[10,2,7]]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 2   Kissan        V   NaN   9.8  10.0     A       0
# 7     Mari        N   7.7   8.0   7.1     B       1

# %%
df2.loc[10:15,['SEM2','SEM1']]
# Out:
#     SEM2  SEM1
# 10   9.3   NaN
# 11   8.0   7.7
# 12   9.1   9.8
# 13   9.1   8.9
# 14   9.9   9.3
# 15   9.3   9.9

# %%
df2.iloc[10:14,:3]#row,col
# Out:
#      Names Initials  SEM1
# 10   Kiran        V   NaN
# 11    Maya        N   7.7
# 12   Jolin        K   9.8
# 13  Rajesh        M   8.9

# %%
df2.loc[:7,['Names']]#row,col
# Out:
#     Names
# 0     Joe
# 1  Rajesh
# 2  Kissan
# 3    Mary
# 4    Jeen
# 5     Raj
# 6  Hassan
# 7    Mari

# %%
df2.loc[df['Names']=='Joe']
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0   Joe        K   9.8  10.0   9.9    A+       1

# %%
df[df.Grade=='A']
df[df.SEM2==10]
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0   Joe        K   9.8  10.0   9.9    A+       1

# %%
df.loc[df['SEM1']>9.8,['Names']]
# Out:
#      Names
# 2   Kissan
# 6   Hassan
# 15    Sana

# %%
df3=df2.copy()
#df3=df3.dropna
df3
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   NaN   9.8  10.0     A       0
# 3     Mary        N   NaN   8.0   NaN     B       0
# 4     Jeen        K   NaN   9.1   9.9    A+       1
# 5      Raj        M   NaN   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df3.dropna(inplace=True,axis=1)#inplace fun says not to reflect changes in df
df3
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 13  Rajesh        M   9.1     A       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
df3.dropna(inplace=True,how='all')#dropna-drop the both col and row containg null
df3
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 13  Rajesh        M   9.1     A       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
mv=df2['SEM1'].mean()
print(mv)
df2=df2.fillna(mv)#It fills the avg in col(sem1) where it contain null
print(df2)
# Out:
# 8.96
#      Names Initials  SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K  9.80  10.0   9.90    A+       1
# 1   Rajesh        M  8.90   9.1   9.30     A       1
# 2   Kissan        V  8.96   9.8  10.00     A       0
# 3     Mary        N  8.96   8.0   8.96     B       0
# 4     Jeen        K  8.96   9.1   9.90    A+       1
# 5      Raj        M  8.96   9.1   9.30     A       1
# 6   Hassan        V  9.90   9.0   9.20     A       1
# 7     Mari        N  7.70   8.0   7.10     B       1
# 8     Jess        K  8.96   9.1   9.90    A+       1
# 9   Rajini        M  8.96   9.1   9.30     A       0
# 10   Kiran        V  8.96   9.3   9.20     A       0
# 11    Maya        N  7.70   8.0   7.10     B       0
# 12   Jolin        K  9.80   9.1   9.90    A+       1
# 13  Rajesh        M  8.90   9.1   9.30     A       1
# 14    Riya        M  9.30   9.9  10.00     A       1
# 15    Sana        V  9.90   9.3   9.20     A       0
# 16    Mark        N  7.70   8.0   7.00     B       0
